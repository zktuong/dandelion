# %% [markdown]
# # *Dandelion* class
#
# ![dandelion_logo](img/dandelion_logo_illustration.png)
#
# Much of the functions and utility of the `dandelion` package revolves around the `Dandelion` class object. The class will act as an intermediary object for storage and flexible interaction with other tools. This section will run through a quick primer to the `Dandelion` class.

# %% [markdown]
# ***Import modules***

# %%
import os
os.chdir(os.path.expanduser('/Users/kt16/Downloads/dandelion_tutorial/'))
import dandelion as ddl
ddl.logging.print_versions()
# Out:
# dandelion==0.1.3.post2.dev62 pandas==1.2.3 numpy==1.20.1 matplotlib==3.3.4 networkx==2.5 scipy==1.6.1 skbio==0.5.6

# %%
vdj = ddl.read_h5('dandelion_results.h5')
vdj
# Out:
# Dandelion class object with n_obs = 562 and n_contigs = 1130
#     data: 'sequence_id', 'sequence', 'rev_comp', 'productive', 'v_call', 'd_call', 'j_call', 'sequence_alignment', 'germline_alignment', 'junction', 'junction_aa', 'v_cigar', 'd_cigar', 'j_cigar', 'stop_codon', 'vj_in_frame', 'locus', 'junction_length', 'np1_length', 'np2_length', 'v_sequence_start', 'v_sequence_end', 'v_germline_start', 'v_germline_end', 'd_sequence_start', 'd_sequence_end', 'd_germline_start', 'd_germline_end', 'j_sequence_start', 'j_sequence_end', 'j_germline_start', 'j_germline_end', 'v_score', 'v_identity', 'v_support', 'd_score', 'd_identity', 'd_support', 'j_score', 'j_identity', 'j_support', 'fwr1', 'fwr2', 'fwr3', 'fwr4', 'cdr1', 'cdr2', 'cdr3', 'cell_id', 'c_call', 'consensus_count', 'umi_count', 'v_call_10x', 'd_call_10x', 'j_call_10x', 'junction_10x', 'junction_10x_aa', 'v_call_genotyped', 'germline_alignment_d_mask', 'sample_id', 'c_sequence_alignment', 'c_germline_alignment', 'c_sequence_start', 'c_sequence_end', 'c_score', 'c_identity', 'c_support', 'c_call_10x', 'junction_aa_length', 'fwr1_aa', 'fwr2_aa', 'fwr3_aa', 'fwr4_aa', 'cdr1_aa', 'cdr2_aa', 'cdr3_aa', 'sequence_alignment_aa', 'v_sequence_alignment_aa', 'd_sequence_alignment_aa', 'j_sequence_alignment_aa', 'mu_count', 'duplicate_count', 'clone_id', 'changeo_clone_id'
#     metadata: 'clone_id', 'clone_id_by_size', 'sample_id', 'locus_VDJ', 'locus_VJ', 'productive_VDJ', 'productive_VJ', 'v_call_genotyped_VDJ', 'v_call_genotyped_VJ', 'j_call_VDJ', 'j_call_VJ', 'c_call_VDJ', 'c_call_VJ', 'duplicate_count_VDJ_0', 'duplicate_count_VDJ_1', 'duplicate_count_VDJ_2', 'duplicate_count_VJ_0', 'duplicate_count_VJ_1', 'junction_aa_VDJ', 'junction_aa_VJ', 'status', 'status_summary', 'productive', 'productive_summary', 'isotype', 'isotype_summary', 'vdj_status', 'vdj_status_summary', 'constant_status_summary', 'changeo_clone_id'
#     distance: 'VDJ_0', 'VDJ_1', 'VDJ_2', 'VJ_0', 'VJ_1'
#     edges: 'source', 'target', 'weight'
#     layout: layout for 562 vertices, layout for 29 vertices
#     graph: networkx graph of 562 vertices, networkx graph of 29 vertices

# %% [markdown]
# Basically, the object can be summarized in the following illustration:
#
# ![dandelion_class <](img/dandelion_class.png)

# %% [markdown]
# Essentially, the `.data` slot holds the AIRR contig table while the `.metadata` holds a collapsed version that is compatible with combining with `AnnData`'s `.obs` slot. You can retrieve these slots like a typical class object; for example, if I want the metadata:

# %%
vdj.metadata
# Out:
#                                           clone_id clone_id_by_size  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG     131_4_1_58                2
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC     17_1_1_163                4
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG     146_2_1_38                8
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG      22_2_1_55               11
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA     59_3_2_308               10
# ...                                            ...              ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  116_2_1_191              353
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA   40_5_2_289              382
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA   71_7_1_249              481
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA   117_3_2_56              463
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG   34_1_1_127              402
#
#                                                   sample_id locus_VDJ  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG      sc5p_v2_hs_PBMC_1k       IGH
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC      sc5p_v2_hs_PBMC_1k       IGH
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG      sc5p_v2_hs_PBMC_1k       IGH
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG      sc5p_v2_hs_PBMC_1k       IGH
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA      sc5p_v2_hs_PBMC_1k       IGH
# ...                                                     ...       ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  vdj_nextgem_hs_pbmc3       IGH
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA  vdj_nextgem_hs_pbmc3       IGH
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA  vdj_nextgem_hs_pbmc3       IGH
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA  vdj_nextgem_hs_pbmc3       IGH
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG  vdj_nextgem_hs_pbmc3       IGH
#
#                                       locus_VJ productive_VDJ productive_VJ  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG        IGK           True          True
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC        IGL           True          True
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG        IGL           True          True
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG        IGL           True          True
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA        IGK           True          True
# ...                                        ...            ...           ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT      IGK           True          True
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA      IGL           True          True
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA      IGK           True          True
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA      IGL           True          True
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG      IGL           True          True
#
#                                       v_call_genotyped_VDJ  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG               IGHV4-59
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC               IGHV3-15
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG               IGHV4-39
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG                IGHV1-3
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA               IGHV4-59
# ...                                                    ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT             IGHV3-15
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA              IGHV1-2
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA             IGHV3-15
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA              IGHV3-7
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG              IGHV2-5
#
#                                       v_call_genotyped_VJ j_call_VDJ  ...  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG               IGKV4-1      IGHJ6  ...
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC              IGLV2-23      IGHJ3  ...
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG              IGLV3-21      IGHJ5  ...
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG              IGLV1-51      IGHJ6  ...
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA              IGKV3-15      IGHJ4  ...
# ...                                                   ...        ...  ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  IGKV2-28|IGKV2D-28      IGHJ6  ...
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA            IGLV2-14      IGHJ4  ...
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA  IGKV1D-39|IGKV1-39      IGHJ4  ...
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA            IGLV1-51      IGHJ6  ...
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG            IGLV1-47      IGHJ4  ...
#
#                                           status status_summary   productive  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG    IGH + IGK      IGH + IGK  True + True
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC    IGH + IGL      IGH + IGL  True + True
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG    IGH + IGL      IGH + IGL  True + True
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG    IGH + IGL      IGH + IGL  True + True
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA    IGH + IGK      IGH + IGK  True + True
# ...                                          ...            ...          ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  IGH + IGK      IGH + IGK  True + True
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA  IGH + IGL      IGH + IGL  True + True
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA  IGH + IGK      IGH + IGK  True + True
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA  IGH + IGL      IGH + IGL  True + True
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG  IGH + IGL      IGH + IGL  True + True
#
#                                        productive_summary  isotype  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG           True + True      IgM
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC           True + True      IgM
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG           True + True      IgA
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG           True + True      IgM
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA           True + True      IgM
# ...                                                   ...      ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT         True + True      IgM
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA         True + True      IgM
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA         True + True      IgM
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA         True + True      IgM
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG         True + True      IgM
#
#                                        isotype_summary           vdj_status  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG                IgM      Single + Single
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC                IgM      Single + Single
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG                IgA  Single + Multi_VJ_j
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG                IgM  Single + Multi_VJ_j
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA                IgM      Single + Single
# ...                                                ...                  ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT              IgM  Single + Multi_VJ_v
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA              IgM  Single + Multi_VJ_j
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA              IgM  Single + Multi_VJ_v
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA              IgM  Single + Multi_VJ_j
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG              IgM  Single + Multi_VJ_j
#
#                                        vdj_status_summary  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG                Single
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC                Single
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG                Single
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG                Single
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA                Single
# ...                                                   ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT              Single
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA              Single
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA              Single
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA              Single
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG              Single
#
#                                       constant_status_summary changeo_clone_id
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG                    Single              8_0
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC                    Single             63_1
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG                    Single             67_2
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG                    Single             72_3
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA                    Single             57_4
# ...                                                       ...              ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT                  Single          294_537
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA                  Single          465_538
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA                  Single          400_539
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA                  Single          292_540
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG                  Single          488_541
#
# [562 rows x 30 columns]

# %% [markdown]
# ### copy
#
# You can deep copy the `Dandelion` object to another variable which will inherit all slots:

# %%
vdj2 = vdj.copy()
vdj2.metadata
# Out:
#                                           clone_id clone_id_by_size  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG     131_4_1_58                2
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC     17_1_1_163                4
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG     146_2_1_38                8
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG      22_2_1_55               11
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA     59_3_2_308               10
# ...                                            ...              ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  116_2_1_191              353
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA   40_5_2_289              382
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA   71_7_1_249              481
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA   117_3_2_56              463
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG   34_1_1_127              402
#
#                                                   sample_id locus_VDJ  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG      sc5p_v2_hs_PBMC_1k       IGH
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC      sc5p_v2_hs_PBMC_1k       IGH
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG      sc5p_v2_hs_PBMC_1k       IGH
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG      sc5p_v2_hs_PBMC_1k       IGH
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA      sc5p_v2_hs_PBMC_1k       IGH
# ...                                                     ...       ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  vdj_nextgem_hs_pbmc3       IGH
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA  vdj_nextgem_hs_pbmc3       IGH
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA  vdj_nextgem_hs_pbmc3       IGH
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA  vdj_nextgem_hs_pbmc3       IGH
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG  vdj_nextgem_hs_pbmc3       IGH
#
#                                       locus_VJ productive_VDJ productive_VJ  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG        IGK           True          True
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC        IGL           True          True
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG        IGL           True          True
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG        IGL           True          True
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA        IGK           True          True
# ...                                        ...            ...           ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT      IGK           True          True
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA      IGL           True          True
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA      IGK           True          True
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA      IGL           True          True
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG      IGL           True          True
#
#                                       v_call_genotyped_VDJ  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG               IGHV4-59
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC               IGHV3-15
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG               IGHV4-39
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG                IGHV1-3
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA               IGHV4-59
# ...                                                    ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT             IGHV3-15
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA              IGHV1-2
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA             IGHV3-15
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA              IGHV3-7
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG              IGHV2-5
#
#                                       v_call_genotyped_VJ j_call_VDJ  ...  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG               IGKV4-1      IGHJ6  ...
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC              IGLV2-23      IGHJ3  ...
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG              IGLV3-21      IGHJ5  ...
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG              IGLV1-51      IGHJ6  ...
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA              IGKV3-15      IGHJ4  ...
# ...                                                   ...        ...  ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  IGKV2-28|IGKV2D-28      IGHJ6  ...
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA            IGLV2-14      IGHJ4  ...
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA  IGKV1D-39|IGKV1-39      IGHJ4  ...
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA            IGLV1-51      IGHJ6  ...
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG            IGLV1-47      IGHJ4  ...
#
#                                           status status_summary   productive  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG    IGH + IGK      IGH + IGK  True + True
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC    IGH + IGL      IGH + IGL  True + True
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG    IGH + IGL      IGH + IGL  True + True
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG    IGH + IGL      IGH + IGL  True + True
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA    IGH + IGK      IGH + IGK  True + True
# ...                                          ...            ...          ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  IGH + IGK      IGH + IGK  True + True
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA  IGH + IGL      IGH + IGL  True + True
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA  IGH + IGK      IGH + IGK  True + True
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA  IGH + IGL      IGH + IGL  True + True
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG  IGH + IGL      IGH + IGL  True + True
#
#                                        productive_summary  isotype  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG           True + True      IgM
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC           True + True      IgM
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG           True + True      IgA
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG           True + True      IgM
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA           True + True      IgM
# ...                                                   ...      ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT         True + True      IgM
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA         True + True      IgM
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA         True + True      IgM
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA         True + True      IgM
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG         True + True      IgM
#
#                                        isotype_summary           vdj_status  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG                IgM      Single + Single
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC                IgM      Single + Single
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG                IgA  Single + Multi_VJ_j
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG                IgM  Single + Multi_VJ_j
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA                IgM      Single + Single
# ...                                                ...                  ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT              IgM  Single + Multi_VJ_v
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA              IgM  Single + Multi_VJ_j
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA              IgM  Single + Multi_VJ_v
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA              IgM  Single + Multi_VJ_j
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG              IgM  Single + Multi_VJ_j
#
#                                        vdj_status_summary  \
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG                Single
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC                Single
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG                Single
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG                Single
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA                Single
# ...                                                   ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT              Single
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA              Single
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA              Single
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA              Single
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG              Single
#
#                                       constant_status_summary changeo_clone_id
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG                    Single              8_0
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC                    Single             63_1
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG                    Single             67_2
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG                    Single             72_3
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA                    Single             57_4
# ...                                                       ...              ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT                  Single          294_537
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA                  Single          465_538
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA                  Single          400_539
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA                  Single          292_540
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG                  Single          488_541
#
# [562 rows x 30 columns]

# %% [markdown]
# ### Retrieving entries with `update_metadata`
#
# The `.metadata` slot in Dandelion class automatically initializes whenever the `.data` slot is filled. However, it only returns a standard number of columns that are pre-specified. To retrieve other columns from the `.data` slot, we can update the metadata with `ddl.update_metadata` and specify the option `retrieve`.
#
# The following options determine how the retrieval is completed:
#
# `split` - splits the retrieval into heavy and light chains calls.
#
# `split_locus` - smiliar to `split` but splits the retrieval to `IGH/IGK/IGL`.
#
# `collapse` - Adds a `|` to separate every element.
#
# `combine` - similar to `collapse` but only retains unique elements (separated by a `|` if multiple are found).

# %% [markdown]
# ***Example 1 : retrieving junction amino acid sequences***

# %%
ddl.update_metadata(vdj, retrieve = 'd_call')
vdj
# Out:
# Dandelion class object with n_obs = 562 and n_contigs = 1130
#     data: 'sequence_id', 'sequence', 'rev_comp', 'productive', 'v_call', 'd_call', 'j_call', 'sequence_alignment', 'germline_alignment', 'junction', 'junction_aa', 'v_cigar', 'd_cigar', 'j_cigar', 'stop_codon', 'vj_in_frame', 'locus', 'junction_length', 'np1_length', 'np2_length', 'v_sequence_start', 'v_sequence_end', 'v_germline_start', 'v_germline_end', 'd_sequence_start', 'd_sequence_end', 'd_germline_start', 'd_germline_end', 'j_sequence_start', 'j_sequence_end', 'j_germline_start', 'j_germline_end', 'v_score', 'v_identity', 'v_support', 'd_score', 'd_identity', 'd_support', 'j_score', 'j_identity', 'j_support', 'fwr1', 'fwr2', 'fwr3', 'fwr4', 'cdr1', 'cdr2', 'cdr3', 'cell_id', 'c_call', 'consensus_count', 'umi_count', 'v_call_10x', 'd_call_10x', 'j_call_10x', 'junction_10x', 'junction_10x_aa', 'v_call_genotyped', 'germline_alignment_d_mask', 'sample_id', 'c_sequence_alignment', 'c_germline_alignment', 'c_sequence_start', 'c_sequence_end', 'c_score', 'c_identity', 'c_support', 'c_call_10x', 'junction_aa_length', 'fwr1_aa', 'fwr2_aa', 'fwr3_aa', 'fwr4_aa', 'cdr1_aa', 'cdr2_aa', 'cdr3_aa', 'sequence_alignment_aa', 'v_sequence_alignment_aa', 'd_sequence_alignment_aa', 'j_sequence_alignment_aa', 'mu_count', 'duplicate_count', 'clone_id', 'changeo_clone_id'
#     metadata: 'clone_id', 'clone_id_by_size', 'sample_id', 'locus_VDJ', 'locus_VJ', 'productive_VDJ', 'productive_VJ', 'v_call_genotyped_VDJ', 'v_call_genotyped_VJ', 'j_call_VDJ', 'j_call_VJ', 'c_call_VDJ', 'c_call_VJ', 'duplicate_count_VDJ_0', 'duplicate_count_VDJ_1', 'duplicate_count_VDJ_2', 'duplicate_count_VJ_0', 'duplicate_count_VJ_1', 'junction_aa_VDJ', 'junction_aa_VJ', 'status', 'status_summary', 'productive', 'productive_summary', 'isotype', 'isotype_summary', 'vdj_status', 'vdj_status_summary', 'constant_status_summary', 'changeo_clone_id', 'd_call_VDJ', 'd_call_VJ'
#     distance: 'VDJ_0', 'VDJ_1', 'VDJ_2', 'VJ_0', 'VJ_1'
#     edges: 'source', 'target', 'weight'
#     layout: layout for 562 vertices, layout for 29 vertices
#     graph: networkx graph of 562 vertices, networkx graph of 29 vertices

# %% [markdown]
# Note the additional `d_call` heavy and light columns in the metadata slot.

# %% [markdown]
# By default, `dandelion` will not try to merge numerical columns as it can create mixed dtype columns.

# %% [markdown]
# ***Example 2 : editing clone_id column***
#
# Perhaps you want to have a bit more control with how clones are called. We can edit this directly from the `.data` slot and retrieve accordingly.

# %%
# if we only want to keep the light chain clone assignment 
clones = []
for clone in vdj.data['clone_id']:
    if '|' in clone: # this is because clones were merged into the the same column if they have different pairing of BCR combinations
        clone_list = clone.split('|')
        clones.append('|'.join(list(set([clone_2.rsplit('_', 1)[0] if clone_2.count('_') == 3 else clone_2 for clone_2 in clone_list]))))
    else:
        if clone.count('_') == 3: # this means it's looking for X_X_X_X, 3 underscores
            clones.append(clone.rsplit('_', 1)[0]) # split the 3rd underscore but only keep the first entry
        else:
            clones.append(clone)
vdj.data['clone_id_heavy_only'] = clones
ddl.update_metadata(vdj, retrieve = 'clone_id_heavy_only', split = False, collapse = True)
vdj.metadata[['clone_id', 'clone_id_heavy_only']]
# Out:
#                                           clone_id clone_id_heavy_only
# sc5p_v2_hs_PBMC_1k_ACACTGATCGGTTCGG     131_4_1_58             131_4_1
# sc5p_v2_hs_PBMC_1k_CCGGTAGGTCAGAAGC     17_1_1_163              17_1_1
# sc5p_v2_hs_PBMC_1k_CGATCGGAGATGTCGG     146_2_1_38             146_2_1
# sc5p_v2_hs_PBMC_1k_CGGACGTGTTGATTCG      22_2_1_55              22_2_1
# sc5p_v2_hs_PBMC_1k_GTACGTACAGCCTATA     59_3_2_308              59_3_2
# ...                                            ...                 ...
# vdj_nextgem_hs_pbmc3_TTCTCAACACATCTTT  116_2_1_191             116_2_1
# vdj_nextgem_hs_pbmc3_TTCTCCTAGGGCACTA   40_5_2_289              40_5_2
# vdj_nextgem_hs_pbmc3_TTCTTAGCAAACGCGA   71_7_1_249              71_7_1
# vdj_nextgem_hs_pbmc3_TTTATGCTCCGCATAA   117_3_2_56             117_3_2
# vdj_nextgem_hs_pbmc3_TTTGCGCTCCAGTATG   34_1_1_127              34_1_1
#
# [562 rows x 2 columns]

# %% [markdown]
# ### `concat`enating multiple objects
#
# This is a simple function to concatenate (append) two or more `Dandelion` class, or `pandas` dataframes.

# %%
# for example, the original dandelion class has 838 unique cell barcodes and 1700 contigs
vdj
# Out:
# Dandelion class object with n_obs = 562 and n_contigs = 1130
#     data: 'sequence_id', 'sequence', 'rev_comp', 'productive', 'v_call', 'd_call', 'j_call', 'sequence_alignment', 'germline_alignment', 'junction', 'junction_aa', 'v_cigar', 'd_cigar', 'j_cigar', 'stop_codon', 'vj_in_frame', 'locus', 'junction_length', 'np1_length', 'np2_length', 'v_sequence_start', 'v_sequence_end', 'v_germline_start', 'v_germline_end', 'd_sequence_start', 'd_sequence_end', 'd_germline_start', 'd_germline_end', 'j_sequence_start', 'j_sequence_end', 'j_germline_start', 'j_germline_end', 'v_score', 'v_identity', 'v_support', 'd_score', 'd_identity', 'd_support', 'j_score', 'j_identity', 'j_support', 'fwr1', 'fwr2', 'fwr3', 'fwr4', 'cdr1', 'cdr2', 'cdr3', 'cell_id', 'c_call', 'consensus_count', 'umi_count', 'v_call_10x', 'd_call_10x', 'j_call_10x', 'junction_10x', 'junction_10x_aa', 'v_call_genotyped', 'germline_alignment_d_mask', 'sample_id', 'c_sequence_alignment', 'c_germline_alignment', 'c_sequence_start', 'c_sequence_end', 'c_score', 'c_identity', 'c_support', 'c_call_10x', 'junction_aa_length', 'fwr1_aa', 'fwr2_aa', 'fwr3_aa', 'fwr4_aa', 'cdr1_aa', 'cdr2_aa', 'cdr3_aa', 'sequence_alignment_aa', 'v_sequence_alignment_aa', 'd_sequence_alignment_aa', 'j_sequence_alignment_aa', 'mu_count', 'duplicate_count', 'clone_id', 'changeo_clone_id', 'clone_id_heavy_only'
#     metadata: 'clone_id', 'clone_id_by_size', 'sample_id', 'locus_VDJ', 'locus_VJ', 'productive_VDJ', 'productive_VJ', 'v_call_genotyped_VDJ', 'v_call_genotyped_VJ', 'j_call_VDJ', 'j_call_VJ', 'c_call_VDJ', 'c_call_VJ', 'duplicate_count_VDJ_0', 'duplicate_count_VDJ_1', 'duplicate_count_VDJ_2', 'duplicate_count_VJ_0', 'duplicate_count_VJ_1', 'junction_aa_VDJ', 'junction_aa_VJ', 'status', 'status_summary', 'productive', 'productive_summary', 'isotype', 'isotype_summary', 'vdj_status', 'vdj_status_summary', 'constant_status_summary', 'changeo_clone_id', 'd_call_VDJ', 'd_call_VJ', 'clone_id_heavy_only'
#     distance: 'VDJ_0', 'VDJ_1', 'VDJ_2', 'VJ_0', 'VJ_1'
#     edges: 'source', 'target', 'weight'
#     layout: layout for 562 vertices, layout for 29 vertices
#     graph: networkx graph of 562 vertices, networkx graph of 29 vertices

# %%
# now it has 5100 contigs instead, and the metadata should also be properly populated
vdj_concat = ddl.concat([vdj, vdj, vdj])
vdj_concat
# Out:
# Dandelion class object with n_obs = 562 and n_contigs = 3390
#     data: 'sequence_id', 'sequence', 'rev_comp', 'productive', 'v_call', 'd_call', 'j_call', 'sequence_alignment', 'germline_alignment', 'junction', 'junction_aa', 'v_cigar', 'd_cigar', 'j_cigar', 'stop_codon', 'vj_in_frame', 'locus', 'junction_length', 'np1_length', 'np2_length', 'v_sequence_start', 'v_sequence_end', 'v_germline_start', 'v_germline_end', 'd_sequence_start', 'd_sequence_end', 'd_germline_start', 'd_germline_end', 'j_sequence_start', 'j_sequence_end', 'j_germline_start', 'j_germline_end', 'v_score', 'v_identity', 'v_support', 'd_score', 'd_identity', 'd_support', 'j_score', 'j_identity', 'j_support', 'fwr1', 'fwr2', 'fwr3', 'fwr4', 'cdr1', 'cdr2', 'cdr3', 'cell_id', 'c_call', 'consensus_count', 'umi_count', 'v_call_10x', 'd_call_10x', 'j_call_10x', 'junction_10x', 'junction_10x_aa', 'v_call_genotyped', 'germline_alignment_d_mask', 'sample_id', 'c_sequence_alignment', 'c_germline_alignment', 'c_sequence_start', 'c_sequence_end', 'c_score', 'c_identity', 'c_support', 'c_call_10x', 'junction_aa_length', 'fwr1_aa', 'fwr2_aa', 'fwr3_aa', 'fwr4_aa', 'cdr1_aa', 'cdr2_aa', 'cdr3_aa', 'sequence_alignment_aa', 'v_sequence_alignment_aa', 'd_sequence_alignment_aa', 'j_sequence_alignment_aa', 'mu_count', 'duplicate_count', 'clone_id', 'changeo_clone_id', 'clone_id_heavy_only'
#     metadata: 'clone_id', 'clone_id_by_size', 'sample_id', 'locus_VDJ', 'locus_VJ', 'productive_VDJ', 'productive_VJ', 'v_call_genotyped_VDJ', 'v_call_genotyped_VJ', 'j_call_VDJ', 'j_call_VJ', 'c_call_VDJ', 'c_call_VJ', 'duplicate_count_VDJ_0', 'duplicate_count_VDJ_1', 'duplicate_count_VDJ_2', 'duplicate_count_VDJ_3', 'duplicate_count_VDJ_4', 'duplicate_count_VDJ_5', 'duplicate_count_VDJ_6', 'duplicate_count_VDJ_7', 'duplicate_count_VDJ_8', 'duplicate_count_VJ_0', 'duplicate_count_VJ_1', 'duplicate_count_VJ_2', 'duplicate_count_VJ_3', 'duplicate_count_VJ_4', 'duplicate_count_VJ_5', 'junction_aa_VDJ', 'junction_aa_VJ', 'status', 'status_summary', 'productive', 'productive_summary', 'isotype', 'isotype_summary', 'vdj_status', 'vdj_status_summary', 'constant_status_summary'
#     distance: None
#     edges: None
#     layout: None
#     graph: None

# %% [markdown]
# ### read/write
#
# `Dandelion` class can be saved using `.write_h5` and `.write_pkl` functions with accompanying compression methods. `write_h5` primarily uses pandas `to_hdf` library and `write_pkl` just uses pickle. `read_h5` and `read_pkl` functions will read the respective file formats accordingly.

# %%
# %time vdj.write_h5('dandelion_results.h5', complib = 'bzip2')
# Out:
# /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages/pandas/core/generic.py:2621: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['sequence_id', 'sequence', 'v_call', 'd_call', 'j_call',
#        'sequence_alignment', 'germline_alignment', 'junction', 'junction_aa',
#        'v_cigar', 'd_cigar', 'j_cigar', 'locus', 'np2_length',
#        'd_sequence_start', 'd_sequence_end', 'd_germline_start',
#        'd_germline_end', 'd_score', 'd_identity', 'd_support', 'fwr1', 'fwr2',
#        'fwr3', 'fwr4', 'cdr1', 'cdr2', 'cdr3', 'cell_id', 'c_call',
#        'v_call_10x', 'd_call_10x', 'j_call_10x', 'junction_10x',
#        'junction_10x_aa', 'v_call_genotyped', 'germline_alignment_d_mask',
#        'sample_id', 'c_sequence_alignment', 'c_germline_alignment',
#        'c_sequence_start', 'c_sequence_end', 'c_score', 'c_identity',
#        'c_support', 'c_call_10x', 'fwr1_aa', 'fwr2_aa', 'fwr3_aa', 'fwr4_aa',
#        'cdr1_aa', 'cdr2_aa', 'cdr3_aa', 'sequence_alignment_aa',
#        'v_sequence_alignment_aa', 'd_sequence_alignment_aa',
#        'j_sequence_alignment_aa', 'clone_id', 'changeo_clone_id',
#        'clone_id_heavy_only'],
#       dtype='object')]
# CPU times: user 1.05 s, sys: 51.5 ms, total: 1.1 s
# Wall time: 1.12 s

# %%
# %time vdj_1 = ddl.read_h5('dandelion_results.h5')
vdj_1
# Out:
# CPU times: user 419 ms, sys: 37.9 ms, total: 457 ms
# Wall time: 458 ms
# Dandelion class object with n_obs = 562 and n_contigs = 1130
#     data: 'sequence_id', 'sequence', 'rev_comp', 'productive', 'v_call', 'd_call', 'j_call', 'sequence_alignment', 'germline_alignment', 'junction', 'junction_aa', 'v_cigar', 'd_cigar', 'j_cigar', 'stop_codon', 'vj_in_frame', 'locus', 'junction_length', 'np1_length', 'np2_length', 'v_sequence_start', 'v_sequence_end', 'v_germline_start', 'v_germline_end', 'd_sequence_start', 'd_sequence_end', 'd_germline_start', 'd_germline_end', 'j_sequence_start', 'j_sequence_end', 'j_germline_start', 'j_germline_end', 'v_score', 'v_identity', 'v_support', 'd_score', 'd_identity', 'd_support', 'j_score', 'j_identity', 'j_support', 'fwr1', 'fwr2', 'fwr3', 'fwr4', 'cdr1', 'cdr2', 'cdr3', 'cell_id', 'c_call', 'consensus_count', 'umi_count', 'v_call_10x', 'd_call_10x', 'j_call_10x', 'junction_10x', 'junction_10x_aa', 'v_call_genotyped', 'germline_alignment_d_mask', 'sample_id', 'c_sequence_alignment', 'c_germline_alignment', 'c_sequence_start', 'c_sequence_end', 'c_score', 'c_identity', 'c_support', 'c_call_10x', 'junction_aa_length', 'fwr1_aa', 'fwr2_aa', 'fwr3_aa', 'fwr4_aa', 'cdr1_aa', 'cdr2_aa', 'cdr3_aa', 'sequence_alignment_aa', 'v_sequence_alignment_aa', 'd_sequence_alignment_aa', 'j_sequence_alignment_aa', 'mu_count', 'duplicate_count', 'clone_id', 'changeo_clone_id', 'clone_id_heavy_only'
#     metadata: 'clone_id', 'clone_id_by_size', 'sample_id', 'locus_VDJ', 'locus_VJ', 'productive_VDJ', 'productive_VJ', 'v_call_genotyped_VDJ', 'v_call_genotyped_VJ', 'j_call_VDJ', 'j_call_VJ', 'c_call_VDJ', 'c_call_VJ', 'duplicate_count_VDJ_0', 'duplicate_count_VDJ_1', 'duplicate_count_VDJ_2', 'duplicate_count_VJ_0', 'duplicate_count_VJ_1', 'junction_aa_VDJ', 'junction_aa_VJ', 'status', 'status_summary', 'productive', 'productive_summary', 'isotype', 'isotype_summary', 'vdj_status', 'vdj_status_summary', 'constant_status_summary', 'changeo_clone_id', 'd_call_VDJ', 'd_call_VJ', 'clone_id_heavy_only'
#     distance: 'VDJ_0', 'VDJ_1', 'VDJ_2', 'VJ_0', 'VJ_1'
#     edges: 'source', 'target', 'weight'
#     layout: layout for 562 vertices, layout for 29 vertices
#     graph: networkx graph of 562 vertices, networkx graph of 29 vertices

# %% [markdown]
# The read/write times using `pickle` can be situationally faster/slower and file sizes can also be situationally smaller/larger (depending on which compression is used).

# %%
# %time vdj.write_pkl('dandelion_results.pkl.gz')
# Out:
# CPU times: user 4.44 s, sys: 30.9 ms, total: 4.47 s
# Wall time: 4.55 s

# %%
# %time vdj_2 = ddl.read_pkl('dandelion_results.pkl.gz')
vdj_2
# Out:
# CPU times: user 58.7 ms, sys: 6.65 ms, total: 65.3 ms
# Wall time: 68.5 ms
# Dandelion class object with n_obs = 562 and n_contigs = 1130
#     data: 'sequence_id', 'sequence', 'rev_comp', 'productive', 'v_call', 'd_call', 'j_call', 'sequence_alignment', 'germline_alignment', 'junction', 'junction_aa', 'v_cigar', 'd_cigar', 'j_cigar', 'stop_codon', 'vj_in_frame', 'locus', 'junction_length', 'np1_length', 'np2_length', 'v_sequence_start', 'v_sequence_end', 'v_germline_start', 'v_germline_end', 'd_sequence_start', 'd_sequence_end', 'd_germline_start', 'd_germline_end', 'j_sequence_start', 'j_sequence_end', 'j_germline_start', 'j_germline_end', 'v_score', 'v_identity', 'v_support', 'd_score', 'd_identity', 'd_support', 'j_score', 'j_identity', 'j_support', 'fwr1', 'fwr2', 'fwr3', 'fwr4', 'cdr1', 'cdr2', 'cdr3', 'cell_id', 'c_call', 'consensus_count', 'umi_count', 'v_call_10x', 'd_call_10x', 'j_call_10x', 'junction_10x', 'junction_10x_aa', 'v_call_genotyped', 'germline_alignment_d_mask', 'sample_id', 'c_sequence_alignment', 'c_germline_alignment', 'c_sequence_start', 'c_sequence_end', 'c_score', 'c_identity', 'c_support', 'c_call_10x', 'junction_aa_length', 'fwr1_aa', 'fwr2_aa', 'fwr3_aa', 'fwr4_aa', 'cdr1_aa', 'cdr2_aa', 'cdr3_aa', 'sequence_alignment_aa', 'v_sequence_alignment_aa', 'd_sequence_alignment_aa', 'j_sequence_alignment_aa', 'mu_count', 'duplicate_count', 'clone_id', 'changeo_clone_id', 'clone_id_heavy_only'
#     metadata: 'clone_id', 'clone_id_by_size', 'sample_id', 'locus_VDJ', 'locus_VJ', 'productive_VDJ', 'productive_VJ', 'v_call_genotyped_VDJ', 'v_call_genotyped_VJ', 'j_call_VDJ', 'j_call_VJ', 'c_call_VDJ', 'c_call_VJ', 'duplicate_count_VDJ_0', 'duplicate_count_VDJ_1', 'duplicate_count_VDJ_2', 'duplicate_count_VJ_0', 'duplicate_count_VJ_1', 'junction_aa_VDJ', 'junction_aa_VJ', 'status', 'status_summary', 'productive', 'productive_summary', 'isotype', 'isotype_summary', 'vdj_status', 'vdj_status_summary', 'constant_status_summary', 'changeo_clone_id', 'd_call_VDJ', 'd_call_VJ', 'clone_id_heavy_only'
#     distance: 'VDJ_0', 'VDJ_1', 'VDJ_2', 'VJ_0', 'VJ_1'
#     edges: 'source', 'target', 'weight'
#     layout: layout for 562 vertices, layout for 29 vertices
#     graph: networkx graph of 562 vertices, networkx graph of 29 vertices
