# %%
import os
import pandas as pd
os.chdir(os.path.expanduser('/Users/kt16/Documents/Github/dandelion'))
import dandelion as ddl
# change directory to somewhere more workable
os.chdir(os.path.expanduser('/Users/kt16/Documents/Clatworthy_scRNAseq/Ondrej/PIP/'))
# Out:
# /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %% [markdown]
# I will work with the same example from the previous notebook since I have the `AnnData` object saved and vdj table filtered.
#
# #### Set up some variables

# %%
sample = 'Pan_T7918901'
bcr_folder = 'Pan_Immune_BCR/'
gex_folder = 'Pan_Immune_GEX/'
sampledict = ddl.utl.dict_from_table('/Users/kt16/Documents/Clatworthy_scRNAseq/Ondrej/dandelion_files/meta/PIP_sampleInfo_kt16.txt', columns = ('SANGER SAMPLE ID', 'GEX_SAMPLE_ID')) 
clone_file = bcr_folder+sample+'/dandelion/data/all_contig_igblast_gap_genotyped_filtered_clone.tsv'

# %%
ddl.tl.reconstruct_germline(clone_file)

# %%
clone_file2 = bcr_folder+sample+'/dandelion/data/all_contig_igblast_gap_genotyped_filtered_clone_germ-pass.tsv'

# %%
ddl.tl.quantify_mutations(clone_file)

# %%
import r2py.objects
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-7f67c993a5c8> in <module>
# ----> 1 import r2py.objects
#
# ModuleNotFoundError: No module named 'r2py'

# %%
# !pip install rpy2
# Out:
# Collecting rpy2
#   Downloading rpy2-3.3.3.tar.gz (173 kB)
#      |████████████████████████████████| 173 kB 1.8 MB/s eta 0:00:01
# Collecting pytest
#   Downloading pytest-5.4.2-py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from rpy2) (2.11.2)
# Requirement already satisfied: pytz in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from rpy2) (2020.1)
# Collecting tzlocal
#   Downloading tzlocal-2.1-py2.py3-none-any.whl (16 kB)
# Collecting cffi>=1.10.0
#   Using cached cffi-1.14.0-cp37-cp37m-macosx_10_9_x86_64.whl (174 kB)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from pytest->rpy2) (1.6.0)
# Requirement already satisfied: packaging in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from pytest->rpy2) (20.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from pytest->rpy2) (19.3.0)
# Collecting py>=1.5.0
#   Downloading py-1.8.1-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 3.2 MB/s eta 0:00:011
# Collecting more-itertools>=4.0.0
#   Downloading more_itertools-8.3.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 4.1 MB/s  eta 0:00:01
# Collecting pluggy<1.0,>=0.12
#   Using cached pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: wcwidth in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from pytest->rpy2) (0.1.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from jinja2->rpy2) (1.1.1)
# Collecting pycparser
#   Using cached pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->rpy2) (3.1.0)
# Requirement already satisfied: six in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from packaging->pytest->rpy2) (1.14.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/kt16/miniconda3/envs/dandelion/lib/python3.7/site-packages (from packaging->pytest->rpy2) (2.4.7)
# Building wheels for collected packages: rpy2
#   Building wheel for rpy2 (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/kt16/miniconda3/envs/dandelion/bin/python3.7 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-install-zbgnqql1/rpy2/setup.py'"'"'; __file__='"'"'/private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-install-zbgnqql1/rpy2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-wheel-m2vy7qhz
#        cwd: /private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-install-zbgnqql1/rpy2/
#   Complete output (152 lines):
#   cffi mode: CFFI_MODE.ANY
#   running bdist_wheel
#   running build
#   running build_py
#   file _rinterface_cffi_abi.py (for module _rinterface_cffi_abi) not found
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.7
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2
#   copying ./rpy2/situation.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2
#   copying ./rpy2/_rinterface_cffi_build.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2
#   copying ./rpy2/rinterface.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2
#   copying ./rpy2/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#   copying ./rpy2/rlike/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#   copying ./rpy2/rlike/container.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#   copying ./rpy2/rlike/functional.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#   copying ./rpy2/rlike/indexing.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/_rinterface_capi.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/embedded_mswin.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/na_values.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/conversion.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/openrlib.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/bufferprotocol.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/ffi_proxy.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/memorymanagement.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/callbacks.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/sexp.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/embedded.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/functions.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/vectors.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/numpy2ri.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/methods.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/constants.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/conversion.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/packages_utils.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/pandas2ri.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/packages.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/language.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/environments.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/help.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   copying ./rpy2/robjects/robject.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#   copying ./rpy2/robjects/lib/grid.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#   copying ./rpy2/robjects/lib/tidyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#   copying ./rpy2/robjects/lib/ggplot2.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#   copying ./rpy2/robjects/lib/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#   copying ./rpy2/robjects/lib/grdevices.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#   copying ./rpy2/robjects/lib/dbplyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#   copying ./rpy2/robjects/lib/dplyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/interactive
#   copying ./rpy2/interactive/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/interactive
#   copying ./rpy2/interactive/packages.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/interactive
#   copying ./rpy2/interactive/process_revents.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/interactive
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#   copying ./rpy2/ipython/rmagic.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#   copying ./rpy2/ipython/html.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#   copying ./rpy2/ipython/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#   copying ./rpy2/ipython/ggplot.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests
#   copying ./rpy2/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests
#   copying ./rpy2/tests/utils.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_pairlist.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_externalptr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_na.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_openrlib.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_callbacks.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_endr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_byte.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vectors.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_complex.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_memorymanagement.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_int.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_embedded_r.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_numpy.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_bool.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_str.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_bufferprotocol.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_float.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_functions.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_lang.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_vector_list.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_noinitialization.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_symbol.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_environment.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   copying ./rpy2/tests/rinterface/test_sexp.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#   package init file './rpy2/tests/rlike/__init__.py' not found (or not a regular file)
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rlike
#   copying ./rpy2/tests/rlike/test_container.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rlike
#   copying ./rpy2/tests/rlike/test_functional.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rlike
#   copying ./rpy2/tests/rlike/test_indexing.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rlike
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_formula.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_pandas_conversions.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_methods.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_packages.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_robjects.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_conversion_numpy.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_array.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_conversion.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_packages_utils.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_vector_extractdelegator.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_vector.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_vector_factor.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_translated_function.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_function.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_rs4.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_serialization.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_language.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_vector_datetime.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_help.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_environment.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   copying ./rpy2/tests/robjects/test_dataframe.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#   copying ./rpy2/tests/ipython/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#   copying ./rpy2/tests/ipython/test_html.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#   copying ./rpy2/tests/ipython/test_ggplot.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#   copying ./rpy2/tests/ipython/test_rmagic.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#   package init file './rpy2/tests/robjects/lib/__init__.py' not found (or not a regular file)
#   creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#   copying ./rpy2/tests/robjects/lib/test_dbplyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#   copying ./rpy2/tests/robjects/lib/test_grid.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#   copying ./rpy2/tests/robjects/lib/test_grdevices.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#   copying ./rpy2/tests/robjects/lib/test_ggplot2.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#   copying ./rpy2/tests/robjects/lib/test_dplyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#   copying ./rpy2/tests/robjects/lib/test_tidyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#   copying ./rpy2/rinterface_lib/R_API.h -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   copying ./rpy2/rinterface_lib/R_API_eventloop.h -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#   file _rinterface_cffi_abi.py (for module _rinterface_cffi_abi) not found
#   generating cffi module 'build/lib.macosx-10.9-x86_64-3.7/_rinterface_cffi_abi.py'
#   running build_ext
#   generating cffi module 'build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.c'
#   creating build/temp.macosx-10.9-x86_64-3.7
#   building '_rinterface_cffi_api' extension
#   creating build/temp.macosx-10.9-x86_64-3.7/build
#   creating build/temp.macosx-10.9-x86_64-3.7/build/temp.macosx-10.9-x86_64-3.7
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/kt16/miniconda3/envs/dandelion/include -arch x86_64 -I/Users/kt16/miniconda3/envs/dandelion/include -arch x86_64 -DRPY2_RLEN_LONG=True -Irpy2/rinterface_lib/ -I/Users/kt16/miniconda3/envs/dandelion/include/python3.7m -c build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.c -o build/temp.macosx-10.9-x86_64-3.7/build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.o
#   In file included from build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.c:541:
#   rpy2/rinterface_lib/R_API.h:201:25: warning: this function declaration is not a prototype [-Wstrict-prototypes]
#   typedef void* (*DL_FUNC)();
#                           ^
#                            void
#   1 warning generated.
#   gcc -bundle -undefined dynamic_lookup -L/Users/kt16/miniconda3/envs/dandelion/lib -arch x86_64 -L/Users/kt16/miniconda3/envs/dandelion/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.9-x86_64-3.7/build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.o -L/usr/local/lib -lpcre -llzma -lbz2 -lz -licucore -ldl -lm -liconv -o build/lib.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.abi3.so -fopenmp -F/Library/Frameworks/R.framework/.. -framework R
#   clang: error: unsupported option '-fopenmp'
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for rpy2
#   Running setup.py clean for rpy2
# Failed to build rpy2
# Installing collected packages: py, more-itertools, pluggy, pytest, tzlocal, pycparser, cffi, rpy2
#     Running setup.py install for rpy2 ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/kt16/miniconda3/envs/dandelion/bin/python3.7 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-install-zbgnqql1/rpy2/setup.py'"'"'; __file__='"'"'/private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-install-zbgnqql1/rpy2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-record-gasdsk4_/install-record.txt --single-version-externally-managed --compile --install-headers /Users/kt16/miniconda3/envs/dandelion/include/python3.7m/rpy2
#          cwd: /private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-install-zbgnqql1/rpy2/
#     Complete output (152 lines):
#     cffi mode: CFFI_MODE.ANY
#     running install
#     running build
#     running build_py
#     file _rinterface_cffi_abi.py (for module _rinterface_cffi_abi) not found
#     creating build
#     creating build/lib.macosx-10.9-x86_64-3.7
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2
#     copying ./rpy2/situation.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2
#     copying ./rpy2/_rinterface_cffi_build.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2
#     copying ./rpy2/rinterface.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2
#     copying ./rpy2/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#     copying ./rpy2/rlike/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#     copying ./rpy2/rlike/container.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#     copying ./rpy2/rlike/functional.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#     copying ./rpy2/rlike/indexing.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rlike
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/_rinterface_capi.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/embedded_mswin.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/na_values.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/conversion.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/openrlib.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/bufferprotocol.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/ffi_proxy.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/memorymanagement.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/callbacks.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/sexp.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/embedded.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/functions.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/vectors.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/numpy2ri.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/methods.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/constants.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/conversion.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/packages_utils.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/pandas2ri.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/packages.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/language.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/environments.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/help.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     copying ./rpy2/robjects/robject.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#     copying ./rpy2/robjects/lib/grid.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#     copying ./rpy2/robjects/lib/tidyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#     copying ./rpy2/robjects/lib/ggplot2.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#     copying ./rpy2/robjects/lib/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#     copying ./rpy2/robjects/lib/grdevices.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#     copying ./rpy2/robjects/lib/dbplyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#     copying ./rpy2/robjects/lib/dplyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/robjects/lib
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/interactive
#     copying ./rpy2/interactive/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/interactive
#     copying ./rpy2/interactive/packages.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/interactive
#     copying ./rpy2/interactive/process_revents.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/interactive
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#     copying ./rpy2/ipython/rmagic.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#     copying ./rpy2/ipython/html.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#     copying ./rpy2/ipython/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#     copying ./rpy2/ipython/ggplot.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/ipython
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests
#     copying ./rpy2/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests
#     copying ./rpy2/tests/utils.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_pairlist.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_externalptr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_na.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_openrlib.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_callbacks.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_endr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_byte.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vectors.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_complex.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_memorymanagement.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_int.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_embedded_r.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_numpy.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_bool.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_str.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_bufferprotocol.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_float.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_functions.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_lang.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_vector_list.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_noinitialization.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_symbol.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_environment.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     copying ./rpy2/tests/rinterface/test_sexp.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rinterface
#     package init file './rpy2/tests/rlike/__init__.py' not found (or not a regular file)
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rlike
#     copying ./rpy2/tests/rlike/test_container.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rlike
#     copying ./rpy2/tests/rlike/test_functional.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rlike
#     copying ./rpy2/tests/rlike/test_indexing.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/rlike
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_formula.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_pandas_conversions.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_methods.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_packages.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_robjects.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_conversion_numpy.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_array.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_conversion.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_packages_utils.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_vector_extractdelegator.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_vector.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_vector_factor.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_translated_function.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_function.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_rs4.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_serialization.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_language.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_vector_datetime.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_help.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_environment.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     copying ./rpy2/tests/robjects/test_dataframe.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#     copying ./rpy2/tests/ipython/__init__.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#     copying ./rpy2/tests/ipython/test_html.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#     copying ./rpy2/tests/ipython/test_ggplot.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#     copying ./rpy2/tests/ipython/test_rmagic.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/ipython
#     package init file './rpy2/tests/robjects/lib/__init__.py' not found (or not a regular file)
#     creating build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#     copying ./rpy2/tests/robjects/lib/test_dbplyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#     copying ./rpy2/tests/robjects/lib/test_grid.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#     copying ./rpy2/tests/robjects/lib/test_grdevices.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#     copying ./rpy2/tests/robjects/lib/test_ggplot2.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#     copying ./rpy2/tests/robjects/lib/test_dplyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#     copying ./rpy2/tests/robjects/lib/test_tidyr.py -> build/lib.macosx-10.9-x86_64-3.7/rpy2/tests/robjects/lib
#     copying ./rpy2/rinterface_lib/R_API.h -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     copying ./rpy2/rinterface_lib/R_API_eventloop.h -> build/lib.macosx-10.9-x86_64-3.7/rpy2/rinterface_lib
#     file _rinterface_cffi_abi.py (for module _rinterface_cffi_abi) not found
#     generating cffi module 'build/lib.macosx-10.9-x86_64-3.7/_rinterface_cffi_abi.py'
#     running build_ext
#     generating cffi module 'build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.c'
#     creating build/temp.macosx-10.9-x86_64-3.7
#     building '_rinterface_cffi_api' extension
#     creating build/temp.macosx-10.9-x86_64-3.7/build
#     creating build/temp.macosx-10.9-x86_64-3.7/build/temp.macosx-10.9-x86_64-3.7
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/kt16/miniconda3/envs/dandelion/include -arch x86_64 -I/Users/kt16/miniconda3/envs/dandelion/include -arch x86_64 -DRPY2_RLEN_LONG=True -Irpy2/rinterface_lib/ -I/Users/kt16/miniconda3/envs/dandelion/include/python3.7m -c build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.c -o build/temp.macosx-10.9-x86_64-3.7/build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.o
#     In file included from build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.c:541:
#     rpy2/rinterface_lib/R_API.h:201:25: warning: this function declaration is not a prototype [-Wstrict-prototypes]
#     typedef void* (*DL_FUNC)();
#                             ^
#                              void
#     1 warning generated.
#     gcc -bundle -undefined dynamic_lookup -L/Users/kt16/miniconda3/envs/dandelion/lib -arch x86_64 -L/Users/kt16/miniconda3/envs/dandelion/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.9-x86_64-3.7/build/temp.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.o -L/usr/local/lib -lpcre -llzma -lbz2 -lz -licucore -ldl -lm -liconv -o build/lib.macosx-10.9-x86_64-3.7/_rinterface_cffi_api.abi3.so -fopenmp -F/Library/Frameworks/R.framework/.. -framework R
#     clang: error: unsupported option '-fopenmp'
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/kt16/miniconda3/envs/dandelion/bin/python3.7 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-install-zbgnqql1/rpy2/setup.py'"'"'; __file__='"'"'/private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-install-zbgnqql1/rpy2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/nb/wrd6px6171j52lqpmkljt6vw000l2l/T/pip-record-gasdsk4_/install-record.txt --single-version-externally-managed --compile --install-headers /Users/kt16/miniconda3/envs/dandelion/include/python3.7m/rpy2 Check the logs for full command output.
